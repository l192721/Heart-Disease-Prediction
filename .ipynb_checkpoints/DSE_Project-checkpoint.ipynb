# %%
import pandas as pd
import seaborn as sn
df=pd.read_csv('project1.csv')
df.info()
df.isnull().sum()

# %%
df['PCO2']=df['PCO2'].fillna(df['PCO2'].mean())
df['outcome']=df['outcome'].fillna(df['outcome'].mean())
df['Systolic blood pressure']=df['Systolic blood pressure'].fillna(df['Systolic blood pressure'].mean())
df['Diastolic blood pressure']=df['Diastolic blood pressure'].fillna(df['Diastolic blood pressure'].mean())
df['SP O2']=df['SP O2'].fillna(df['SP O2'].mean())
df['temperature']=df['temperature'].fillna(df['temperature'].mean())
df['Respiratory rate']=df['Respiratory rate'].fillna(df['Respiratory rate'].mean())
df['heart rate']=df['heart rate'].fillna(df['heart rate'].mean())
df['PT']=df['PT'].fillna(df['PT'].mean())
df['Lymphocyte']=df['Lymphocyte'].fillna(df['Lymphocyte'].mean())
df['Neutrophils']=df['Neutrophils'].fillna(df['Neutrophils'].mean())
df['Basophils']=df['Basophils'].fillna(df['Basophils'].mean())
df['BMI']=df['BMI'].fillna(df['BMI'].mean())
df.isnull().sum()

# %%
df.drop_duplicates()

# %%
import seaborn as sns
corrMatrix = df.corr()
fig, ax = plt.subplots(figsize=(18,18)) # Sample figsize in inches
sns.heatmap(corrMatrix, annot=True, linewidths=.5, ax=ax)
plt.show()

# %%
import seaborn as sns
sns.boxplot(x=df['BMI'])

# %%
import seaborn as sns
sns.boxplot(x=df['BMI'])
Q1=df["BMI"].quantile(0.25)
Q2=df["BMI"].quantile(0.75)
low2=Q1-(1.5*(Q2-Q1))
up2=Q2+(1.5*(Q2-Q1))
df.loc[df["BMI"] <low2,"BMI"]=low2
df.loc[df["BMI"] >up2,"BMI"]=up2

# %%
sns.boxplot(df['BMI'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
sns.boxplot(x=df['Basophils'])

# %%
Q1=df["Basophils"].quantile(0.25)
Q2=df["Basophils"].quantile(0.75)
low2=Q1-(1.5*(Q2-Q1))
up2=Q2+(1.5*(Q2-Q1))
df.loc[df["Basophils"] <low2,"Basophils"]=low2
df.loc[df["Basophils"] >up2,"Basophils"]=up2

# %%
sns.boxplot(df['Basophils'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
sns.boxplot(x=df['Neutrophils'])

# %%
Q1=df["Neutrophils"].quantile(0.25)
Q2=df["Neutrophils"].quantile(0.75)
low2=Q1-(1.5*(Q2-Q1))
up2=Q2+(1.5*(Q2-Q1))
df.loc[df["Neutrophils"] <low2,"Neutrophils"]=low2
df.loc[df["Neutrophils"] >up2,"Neutrophils"]=up2
sns.boxplot(df['Neutrophils'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
sns.boxplot(x=df['PCO2'])

# %%
Q1=df["PCO2"].quantile(0.25)
Q2=df["PCO2"].quantile(0.75)
low2=Q1-(1.5*(Q2-Q1))
up2=Q2+(1.5*(Q2-Q1))
df.loc[df["PCO2"] <low2,"PCO2"]=low2
df.loc[df["PCO2"] >up2,"PCO2"]=up2
sns.boxplot(df['PCO2'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
sns.boxplot(x=df['Lymphocyte'])

# %%
Q1=df["Lymphocyte"].quantile(0.25)
Q2=df["Lymphocyte"].quantile(0.75)
low2=Q1-(1.5*(Q2-Q1))
up2=Q2+(1.5*(Q2-Q1))
df.loc[df["Lymphocyte"] <low2,"Lymphocyte"]=low2
df.loc[df["Lymphocyte"] >up2,"Lymphocyte"]=up2
sns.boxplot(x=df['Lymphocyte'])

# %%
import seaborn as sns
sns.boxplot(x=df['PT'])

# %%
Q1=df["PT"].quantile(0.25)
Q2=df["PT"].quantile(0.75)
low2=Q1-(1.5*(Q2-Q1))
up2=Q2+(1.5*(Q2-Q1))
df.loc[df["PT"] <low2,"PT"]=low2
df.loc[df["PT"] >up2,"PT"]=up2
sns.boxplot(df['PT'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
sns.boxplot(x=df['Respiratory rate'])

# %%
Q1=df["Respiratory rate"].quantile(0.25)
Q2=df["Respiratory rate"].quantile(0.75)
low2=Q1-(1.5*(Q2-Q1))
up2=Q2+(1.5*(Q2-Q1))
df.loc[df["Respiratory rate"] <low2,"Respiratory rate"]=low2
df.loc[df["Respiratory rate"] >up2,"Respiratory rate"]=up2
sns.boxplot(x=df['Respiratory rate'])

# %%
import seaborn as sns
sns.boxplot(x=df['temperature'])

# %%
Q1=df["temperature"].quantile(0.25)
Q2=df["temperature"].quantile(0.75)
low2=Q1-(1.5*(Q2-Q1))
up2=Q2+(1.5*(Q2-Q1))
df.loc[df["temperature"] <low2,"temperature"]=low2
df.loc[df["temperature"] >up2,"temperature"]=up2
sns.boxplot(df['temperature'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
sns.boxplot(x=df['SP O2'])

# %%
Q1=df["SP O2"].quantile(0.25)
Q2=df["SP O2"].quantile(0.75)
low2=Q1-(1.5*(Q2-Q1))
up2=Q2+(1.5*(Q2-Q1))
df.loc[df["SP O2"] <low2,"SP O2"]=low2
df.loc[df["SP O2"] >up2,"SP O2"]=up2
sns.boxplot(df['SP O2'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
sns.boxplot(x=df['Diastolic blood pressure'])

# %%
Q1=df["Diastolic blood pressure"].quantile(0.25)
Q2=df["Diastolic blood pressure"].quantile(0.75)
low2=Q1-(1.5*(Q2-Q1))
up2=Q2+(1.5*(Q2-Q1))
df.loc[df["Diastolic blood pressure"] <low2,"Diastolic blood pressure"]=low2
df.loc[df["Diastolic blood pressure"] >up2,"Diastolic blood pressure"]=up2
sns.boxplot(df['Diastolic blood pressure'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
sns.boxplot(x=df['Systolic blood pressure'])

# %%
Q1=df["Systolic blood pressure"].quantile(0.25)
Q2=df["Systolic blood pressure"].quantile(0.75)
low2=Q1-(1.5*(Q2-Q1))
up2=Q2+(1.5*(Q2-Q1))
df.loc[df["Systolic blood pressure"] <low2,"Systolic blood pressure"]=low2
df.loc[df["Systolic blood pressure"] >up2,"Systolic blood pressure"]=up2
sns.boxplot(df['Systolic blood pressure'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
sns.boxplot(x=df['outcome'])

# %%
Q1=df["outcome"].quantile(0.25)
Q2=df["outcome"].quantile(0.75)
low2=Q1-(1.5*(Q2-Q1))
up2=Q2+(1.5*(Q2-Q1))
df.loc[df["outcome"] <low2,"outcome"]=low2
df.loc[df["outcome"] >up2,"outcome"]=up2
sns.boxplot(df['outcome'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
d=df.head()
d.plot.pie(subplots = True,figsize = (400,400))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
df[['ID','outcome','BMI']].plot(kind='hist')
plt.show()

# %%
df[['heart rate','Systolic blood pressure','Diastolic blood pressure','outcome','BMI']].plot(kind='hist')
plt.show()

# %%
df[['hypertensive','atrialfibrillation','COPD','RBC']].plot(kind='hist')
plt.show()

# %%
df['Leucocyte'].plot(kind='hist')
plt.show()

# %%
df['Neutrophils'].plot(kind='hist')
plt.show()

# %%
plt.title("Basophils ")
df['Basophils'].value_counts().plot(kind='pie')
plt.show()

# %%
plt.title("PCO2")
df['PCO2'].value_counts().plot(kind='pie')
plt.show()

# %%
sns.scatterplot(x="Anion gap",y="Magnesium ion",data=df)

# %%
sns.scatterplot(x="hematocrit",y="RBC",data=df)

# %%
sns.scatterplot(x="temperature",y="SP O2",data=df)

# %%
sns.barplot(x="CHD with no MI",y="COPD", data=df)

# %%
df.shape

# %%
sns.barplot(x="gender",y="atrialfibrillation", data=df)

# %%
sns.barplot(x="RBC",y="temperature", data=df)

# %%
X = df.iloc[:, 0:30]
y =df.iloc[:,-1]

# %%
X.head()

# %%
y

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test =train_test_split(X,y,test_size=0.3,random_state=100)

# %%
import joblib
import sys
sys.modules['sklearn.externals.joblib'] = joblib

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector as sfs

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
sfs1 = sfs(lr, k_features=10, forward=True, verbose=2, scoring='neg_mean_squared_error')
sfs1 = sfs1.fit(X, y)

# %%
y=df["BMI"]
x=df[["heart rate"]]
from sklearn.linear_model import LinearRegression
l=LinearRegression()
l.fit(x,y)
y_pred=l.predict(x)
from sklearn.metrics import r2_score
r2_score(y, y_pred)
